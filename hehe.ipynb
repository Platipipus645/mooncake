# %% [markdown]
# <a href="https://colab.research.google.com/github/Platipipus645/mooncake/blob/main/hehe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
pre_loop_closure_filepath ='/content/drive/MyDrive/PRT/pre_loop_closure.poses'

# %%
post_loop_closure_filepath ='/content/drive/MyDrive/PRT/post_loop_closure.poses'

# %%
pre_loop_closure = pd.read_csv(pre_loop_closure_filepath)

# %%
pre_loop_closure.head()
# Out:
#           Time  Rx(Roll)  Ry(Pitch)   Rz(Yaw)         X         Y         Z
# 0  1829.374383  0.000000  -0.000000  0.000000  0.000000  0.000000  0.000000
# 1  1829.574435 -0.000102   0.000104  0.010018 -0.020326  0.123029  0.000831
# 2  1829.674419 -0.000018   0.000057  0.011214 -0.017716  0.167008  0.001554
# 3  1829.874361 -0.000279   0.000270  0.015267 -0.031259  0.319614 -0.003644
# 4  1830.074431 -0.000087   0.000158  0.015232 -0.027398  0.500018 -0.002331

# %%
post_loop_closure = pd.read_csv(post_loop_closure_filepath)

# %%
post_loop_closure.head()
# Out:
#           Time  Rx(Roll)  Ry(Pitch)   Rz(Yaw)         X         Y         Z
# 0  1829.374383  0.000000  -0.000000  0.000000  0.000000  0.000000  0.000000
# 1  1829.574435 -0.000102   0.000104  0.010019 -0.020326  0.123029  0.000831
# 2  1829.674419 -0.000018   0.000057  0.011214 -0.017716  0.167008  0.001554
# 3  1829.874361 -0.000279   0.000270  0.015267 -0.031259  0.319614 -0.003644
# 4  1830.074431 -0.000087   0.000158  0.015232 -0.027398  0.500017 -0.002331

# %%
sns.scatterplot(x=pre_loop_closure['Time'],y=pre_loop_closure['X'])
# Out:
# <Axes: xlabel='Time', ylabel='X'>

# %%
sns.regplot(x=pre_loop_closure['Time'],y=pre_loop_closure['X'])
# Out:
# <Axes: xlabel='Time', ylabel='X'>

# %%
sns.lineplot(data=pre_loop_closure['X'], label='X_pre_lc')
sns.lineplot(data=post_loop_closure['X'], label='X_post_lc')
plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
sns.lineplot(data=pre_loop_closure['Y'],label='Y_pre_lc')
sns.lineplot(data=post_loop_closure['Y'],label='Y_post_lc')
plt.xlabel=('Time')

# %%
sns.lineplot(data=pre_loop_closure['Z'],label='Z_pre_lc')
sns.lineplot(data=post_loop_closure['Z'],label='Z_post_lc')
plt.xlabel=('Time')

# %%
sns.lineplot(data=pre_loop_closure['Rx(Roll)'],label='Roll_pre_lc')
sns.lineplot(data=post_loop_closure['Rx(Roll)'],label='Roll_post_lc')
plt.xlabel=('Time')

# %%
sns.lineplot(data=pre_loop_closure['Ry(Pitch)'],label='Pitch_pre_lc')
sns.lineplot(data=post_loop_closure['Ry(Pitch)'],label='Pitch_post_lc')
plt.xlabel=('Time')

# %%
sns.lineplot(data=pre_loop_closure['Rz(Yaw)'],label='Yaw_pre_lc')
sns.lineplot(data=post_loop_closure['Rz(Yaw)'],label='Yaw_post_lc')
plt.xlabel=('Time')
